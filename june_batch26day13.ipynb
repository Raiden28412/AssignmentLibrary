# %% [markdown]
# <a href="https://colab.research.google.com/github/Raiden28412/AssignmentLibrary/blob/master/june_batch26day13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#create a set of 5 numbers
#add a new element to the set
#remove an element from a set
#chcek if a given element exists in a set
#find the union of two sets

# %%
s={1,2,3,4,5}
s.add(6)
s
s.remove(6)
s
4 in s #to check if the element exists or not
#or

s1={1,2,3,4}
s2={1,3,4,5}
s3=s1.union(s2)
print(s3)
# Out:
# {1, 2, 3, 4, 5}

# %%
#find the sum of given elements in a given list using in built function
l=[]
sum=0
for i in range(5):#to get the elements from the user
  n=int(input(""))
  l.append(n)

l
for i in l:#to find the sum
  sum=sum+i

sum
# Out:
# 1
# 2
# 3
# 4
# 5
# 15

# %%
#find the smallest elemnt in a list without using inbuilt
l=[]

for i in range(5):#to get the elements from the user
  n=int(input(""))
  l.append(n)
s=l[0]

for i in l:
  if i<s:
    s=i
print(s)
# Out:
# 1
# 2
# 4
# 5
# 4
# 1

# %%
#write a program to count the number of even numbers in a element
l=[]
count=0
for i in range(5):#to get the elements from the user
  n=int(input(""))
  l.append(n)
for i in l:
  if i%2==0:
    count+=1
count
# Out:
# 4
# 1
# 7
# 8
# 10
# 3

# %%
#write a program to reverse the list without using inbuilt function
l=[1,2,3,4]
m=l[-1::-1]
print(m)
# Out:
# [4, 3, 2, 1]

# %%
#write a program to find duplicate the elements in a given element
l=[1,2,3,3,3,4,4]
m=[]
d=[]
for i in l:
 if i not in m:
    m.append(i)
 else:
   d.append(i)
s=set(d)
print(s)
print(m)

#alternate method
l=[1,2,3,3,3,4,4]
s=set(l)
for i in s:
  if l.count(i)>=2:
    print(i)
# Out:
# {3, 4}
# [1, 2, 3, 4]
# 3
# 4

# %%
#alternate method
l=[1,2,3,3,3,4,4]
s=set(l)#here its done to getthe unique elemments
for i in s:
  if l.count(i)>1:
    print(i)
# Out:
# 3
# 3
# 3
# 4
# 4

# %%
#write a program to print elements whose is greater than 3 in a given list without converting it into a set
l=[2,1,1,1,1,6,6,7,7,7,7,9]
m=[]
for i in l:
  if l.count(i)>3 and i not in m:
    m.append(i)
# Out:
# [1, 7]

# %%
#list comprehension
#its a compact way to built a list using a single line
#[expression for item in iterable]
#without list comprehension
sq=[]
for i in range(5):
  n=int(input(""))
  sq.append(n**2)
sq
# Out:
# 1
# 2
# 3
# 4
# 5
# [1, 4, 9, 16, 25]

# %%
#with list comprehension
sq=[x**2 for x in range(1,6)]
sq
# Out:
# [1, 4, 9, 16, 25]

# %%
#given a lists(matrix) flaten it into a single list
l=[[1,2,3],[4,5,6],[7,8,9]]
m=[]
for i in l:
 for j in i:
   m.append(j)
m
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
nums=[10,20,30,40,50]
m=len(nums)
m
# Out:
# 5
